# %% [markdown]
# <a href="https://colab.research.google.com/github/41Kasidet/PISA2022-Project/blob/main/3_Convert_BigCSV_to_PARQUET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('PISA_2022_Dataset_Selected_Columns.csv')
df.head(5)
# Out:
#    student_qqq_id Country  Math_Score  Reading_Score  Science_Score  Gender  \
# 0               1     ALB    249.9635       249.8026       301.2603     1.0
# 1               2     ALB    329.5964       288.8999       303.5314     2.0
# 2               3     ALB    338.3428       311.7785       323.6492     2.0
# 3               4     ALB    253.7627       300.7753       210.1502     1.0
# 4               5     ALB    481.7530       486.6689       466.7572     1.0
#
#    International_Grade  Birth_Month  Birth_Year  School_ID  ...  \
# 0                   10          5.0      2006.0     800282  ...
# 1                    9          2.0      2006.0     800115  ...
# 2                    9          8.0      2006.0     800242  ...
# 3                    8          7.0      2006.0     800245  ...
# 4                   10          1.0      2006.0     800285  ...
#
#    Funding_by_Fee_or_Charge  Funding_by_Donate  Funding_by_Others  \
# ...

# %%
df.to_parquet('PISA_2022_Dataset_Selected_Columns.parquet', compression='snappy')
print('Done')
# Out:
# Done

# %% [markdown]
# # Test .parquet

# %%
# !pip install pandas pyarrow

# %%
import pandas as pd
import os

# After Import File to environment
df_parquet = pd.read_parquet('PISA_2022_Dataset_Selected_Columns.parquet')

print("--- ข้อมูล 5 แถวแรก ---")
print(df_parquet.head())

print("\n--- ข้อมูลทางสถิติ/โครงสร้าง ---")
print(df_parquet.info())
# Out:
# --- ข้อมูล 5 แถวแรก ---
#    student_qqq_id Country  Math_Score  Reading_Score  Science_Score  Gender  \
# 0               1     ALB    249.9635       249.8026       301.2603     1.0
# 1               2     ALB    329.5964       288.8999       303.5314     2.0
# 2               3     ALB    338.3428       311.7785       323.6492     2.0
# 3               4     ALB    253.7627       300.7753       210.1502     1.0
# 4               5     ALB    481.7530       486.6689       466.7572     1.0
#
#    International_Grade  Birth_Month  Birth_Year  School_ID  ...  \
# 0                   10          5.0      2006.0     800282  ...
# 1                    9          2.0      2006.0     800115  ...
# 2                    9          8.0      2006.0     800242  ...
# 3                    8          7.0      2006.0     800245  ...
# 4                   10          1.0      2006.0     800285  ...
#
#    Funding_by_Fee_or_Charge  Funding_by_Donate  Funding_by_Others  \
# ...
